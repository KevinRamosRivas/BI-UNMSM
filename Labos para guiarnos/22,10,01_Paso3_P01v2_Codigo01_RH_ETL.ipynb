# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
####se sube de la sesion 01: RH_COD.xlsx
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-41909f55-6be5-4091-a927-9cfe8d05924b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-41909f55-6be5-4091-a927-9cfe8d05924b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_excel('RH_COD.xlsx',sheet_name='Sheet1')

# %%
######actividad 02: filtrado de la data, se eliminan las columnmas que solo tienen un valor
data.hist(bins = 30, figsize=(20,20), color = 'r')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe495fdb390>,
# ...
#       dtype=object)

# %%
####eliminar columnas de 1 valor
data.drop(["EmployeeCount", "StandardHours", "Over18"], axis = 1, inplace = True)

# %%
data = data[['Age','Attrition','DistanceFromHome','Gender','MonthlyIncome','NumCompaniesWorked','YearsAtCompany','Education','EnvironmentSatisfaction','JobInvolvement','YearsInCurrentRole']]

# %%
#### Para Excel files
from google.colab import files

# %%
data.to_excel ('RHv2.xlsx') 
files.download('RHv2.xlsx')

# %%
data.describe()
# Out:
#                Age    Attrition  DistanceFromHome       Gender  MonthlyIncome  \
# count  1470.000000  1470.000000       1470.000000  1470.000000    1470.000000
# mean     36.923810     0.161224          9.192517     0.600000    6502.931293
# std       9.135373     0.367863          8.106864     0.490065    4707.956783
# min      18.000000     0.000000          1.000000     0.000000    1009.000000
# 25%      30.000000     0.000000          2.000000     0.000000    2911.000000
# 50%      36.000000     0.000000          7.000000     1.000000    4919.000000
# 75%      43.000000     0.000000         14.000000     1.000000    8379.000000
# max      60.000000     1.000000         29.000000     1.000000   19999.000000
#
#        NumCompaniesWorked  YearsAtCompany    Education  \
# count         1470.000000     1470.000000  1470.000000
# mean             2.693197        7.008163     2.912925
# std              2.498009        6.126525     1.024165
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1470 non-null   int64
#  1   Attrition                1470 non-null   int64
#  2   DistanceFromHome         1470 non-null   int64
#  3   Gender                   1470 non-null   int64
#  4   MonthlyIncome            1470 non-null   int64
#  5   NumCompaniesWorked       1470 non-null   int64
#  6   YearsAtCompany           1470 non-null   int64
#  7   Education                1470 non-null   int64
#  8   EnvironmentSatisfaction  1470 non-null   int64
#  9   JobInvolvement           1470 non-null   int64
#  10  YearsInCurrentRole       1470 non-null   int64
# dtypes: int64(11)
# memory usage: 126.5 KB

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'DistanceFromHome', 'Gender', 'MonthlyIncome',
#        'NumCompaniesWorked', 'YearsAtCompany', 'Education',
#        'EnvironmentSatisfaction', 'JobInvolvement', 'YearsInCurrentRole'],
#       dtype='object')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame
